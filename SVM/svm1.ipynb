# %% [markdown]
# # Assignment - 3
# # Harshil Dholakiya
# # MSc WMT

# %% [markdown]
# ### Q.1 Implement support vector machine algorithm using sklearn for diabetes prediction analysis.

# %%
import pandas as pd

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics

# %%
X = df.drop("Outcome", axis=1)
Y = df[["Outcome"]].values.ravel()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30, random_state=39)

# %%
#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

print(" Linear Kernel")
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
#  Linear Kernel
# Accuracy: 0.7402597402597403

# %% [markdown]
# ### Q.2 Fine tune algorithm results by changing kernel parameters.

# %%
# Radial basis function (RBF) kernel
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.35,random_state=30)

#Create a svm Classifier
clf1 = svm.SVC(kernel='rbf') # Radial basis function (RBF) kernel

#Train the model using the training sets
clf1.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf1.predict(X_test)

print("Radial basis function (RBF) kernel")
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Radial basis function (RBF) kernel
# Accuracy: 0.7843866171003717

# %%
 # Polynomial kernel
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25,random_state=121)

#Create a svm Classifier
clf2 = svm.SVC(kernel= "poly") # Polynomial kernel

#Train the model using the training sets
clf2.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf2.predict(X_test)

print("Polynomial kernel")
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Polynomial kernel
# Accuracy: 0.796875
